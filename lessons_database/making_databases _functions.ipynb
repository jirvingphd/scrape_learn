# %% [markdown]
# # MAKING SQL DATABASE FOR LESSONS
# ## Resources:
# - https://pythontic.com/pandas/serialization/mysql
# - https://towardsdatascience.com/pandas-and-sql-together-a-premier-league-and-player-scouting-example-b41713a5dd3e

# %% [markdown]
# ## MySQL Basics

# %% [markdown]
# ```python
# ## Load in credentials
# import json
# with open("/Users/jamesirving/.secret/mysql_login.json",'r+') as f:
#     my_login = json.loads(f.read())
# my_login.keys()
#
# ## Create mysql connection
# import mysql.connector
# mydb=  mysql.connector.connect(
#     host='localhost',
#     user=my_login['user'],
#     passwd=my_login['passwd'],
#     database = "testdb"
# )
#
# cur = mydb.cursor()
# ```
#
# ## To Get List of databases
#
# ```python
# cur.execute("SHOW DATABASES")
# databases = cur.fetchall()
# # cur.execute(SELECT
#
# ```
#
# ## To use with pandas
#
# ```python
# import sqlalchemy
# import pymysql
# engine = sqlalchemy.create_engine(f"mysql+pymysql://{my_login['user']}:{my_login['passwd']}@localhost/testdb")
# df = pd.read_sql_table('students',engine)
#
# df.to_sql('students',engine,if_exists='append',index=False)
#                                   ```

# %%
from fsds_100719.imports import *
# Out:
# fsds_1007219  v0.7.22 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_a4f37974_68c1_11eb_895b_acde48001122" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row1_col1" class="data row1 col1" >fsds_100719</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_a4f37974_68c1_11eb_895b_acde48001122row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_a4f37974_68c1_11eb_895b_acde48001122row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %% [markdown]
# # FROM DF TO SQL

# %% [markdown]
# - Questions:
#     - **Can I use a mysql connector or MUST I make my engine with sqlalchemy?**
#         - A: Yes, but you still use the mysql connection for QUERIES. Its only the engine that we need from sqlalchemy. (?)
#     - How to determine location of actual saved database file
#
# https://towardsdatascience.com/pandas-and-sql-together-a-premier-league-and-player-scouting-example-b41713a5dd3e

# %% [markdown]
# # CREATING DATABSE FROM DF COLUMNS AND DTYPES

# %%
import os
import mysql.connector
from fsds.imports import *
# Out:
# fsds v0.2.30 loaded.  Read the docs: https://fs-ds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_a5cb5498_68c1_11eb_9b09_acde48001122" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row1_col1" class="data row1 col1" >fsds</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_a5cb5498_68c1_11eb_9b09_acde48001122row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %% [markdown]
# - All of the above code has been replaced by functions_lessons.py

# %%
## LOAD IN SQL FUNCTIONS
# %load_ext autoreload
# %autoreload 2
import functions_lessons as fn

# %%
mydb,cur,engine = fn.get_sql_connectors(database='lessons')
# Out:
# [i] DATABASES FOUND:
# ('information_schema',)
# ('lessons',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
folder = '/Users/jamesirving/Google Drive/_Teaching Docs/Lessons/'
sorted(os.listdir(folder))
# Out:
# ['Combined List of Lessons.gsheet',
#  'Combined List of Lessons.xlsx',
#  'Presentations',
#  'Source Files',
#  'Videos of Canvas Training Sessions.gshortcut',
#  'canvas_lecture_schedule_011121.gsheet']

# %%
df = pd.read_excel(folder+'Combined List of Lessons.xlsx',sheet_name='Lessons').reset_index()
df.head(2)
# Out:
#    index     Title    Type Est. Student time  \
# 0      0   Welcome  Readme          00:05:00
# 1      1  Blogging  Readme          00:15:00
#
#                                            V2.1 repo  \
# 0  https://github.com/learn-co-curriculum/dsc-wel...
# 1  https://github.com/learn-co-curriculum/dsc-wel...
#
#                                       GitHub Repo V2  \
# 0  https://github.com/learn-co-curriculum/dsc-wel...
# 1  https://github.com/learn-co-curriculum/dsc-wel...
#
#   Notes (from Learning Goals) Section number Section Title   Module
# 0                         NaN     Section 00       Welcome  Welcome
# 1                         NaN     Section 00       Welcome  Welcome

# %%
## Make students table
DATABSE  = 'lessons'
TABLE ='repos'

# %%
df = fn.clean_df_columns_for_sql(df)
df
# Out:
#      number_index                                             Title RepoType  \
# 0               0                                           Welcome   Readme
# 1               1                                          Blogging   Readme
# 2               2  Getting Started with Data Science - Introduction   Readme
# 3               3                   Problems Data Science Can Solve   Readme
# 4               4                          The Data Science Process   Readme
# ..            ...                                               ...      ...
# 619           619                    Spark Reading Into A DataFrame      NaN
# 620           620                        Setting Up Scala and Spark      NaN
# 621           621                         Spark Docker Installation      NaN
# 622           622                           Spark DataFrame Joining      NaN
# 623           623                       Machine Learning With Spark      NaN
#
#     Est_Student_time                                           V21_repo  \
# 0           00:05:00  https://github.com/learn-co-curriculum/dsc-wel...
# 1           00:15:00  https://github.com/learn-co-curriculum/dsc-wel...
# 2           00:05:00  https://github.com/learn-co-curriculum/dsc-int...
# 3           00:10:00  https://github.com/learn-co-curriculum/dsc-pro...
# 4           00:10:00  https://github.com/learn-co-curriculum/dsc-the...
# ..               ...                                                ...
# 619              NaN                                                NaN
# 620              NaN                                                NaN
# 621              NaN                                                NaN
# 622              NaN                                                NaN
# 623              NaN                                                NaN
#
#                                         GitHub_Repo_V2  \
# 0    https://github.com/learn-co-curriculum/dsc-wel...
# 1    https://github.com/learn-co-curriculum/dsc-wel...
# 2    https://github.com/learn-co-curriculum/dsc-int...
# 3    https://github.com/learn-co-curriculum/dsc-pro...
# 4    https://github.com/learn-co-curriculum/dsc-the...
# ..                                                 ...
# 619  https://github.com/learn-co-curriculum/dsc-ent...
# 620  https://github.com/learn-co-curriculum/dsc-ent...
# 621  https://github.com/learn-co-curriculum/dsc-ent...
# 622  https://github.com/learn-co-curriculum/dsc-ent...
# 623  https://github.com/learn-co-curriculum/dsc-ent...
#
#                         Notes_from_Learning_Goals  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3    Describe the problems data science can solve
# 4        Describe the full data science process\n
# ..                                            ...
# 619                                           NaN
# 620                                           NaN
# 621                                           NaN
# 622                                           NaN
# 623                                           NaN
#
#                                         Section_number  \
# 0                                           Section 00
# 1                                           Section 00
# 2                                           Section 01
# 3                                           Section 01
# 4                                           Section 01
# ..                                                 ...
# 619  Section Enterprise 2  [not part of core curric...
# 620  Section Enterprise 2  [not part of core curric...
# 621  Section Enterprise 2  [not part of core curric...
# 622  Section Enterprise 2  [not part of core curric...
# 623  Section Enterprise 2  [not part of core curric...
#
#                          Section_Title      Module
# 0                              Welcome     Welcome
# 1                              Welcome     Welcome
# 2    Getting Started with Data Science       Mod 1
# 3    Getting Started with Data Science       Mod 1
# 4    Getting Started with Data Science       Mod 1
# ..                                 ...         ...
# 619                              Spark  Enterprise
# 620                              Spark  Enterprise
# 621                              Spark  Enterprise
# 622                              Spark  Enterprise
# 623                              Spark  Enterprise
#
# [624 rows x 10 columns]

# %% [markdown]
# # BOOKMARK

# %% [markdown]
# ## Preparing commands

# %% [markdown]
# - Must create the list of variables to add to the table/
# - PRIMARY KEY column cannot be TEXT (make VARCHAR if tesxt))

# %%
# [print(dtypes[i]) for i in range(len(df.columns))];

# %%
## Get Object columns and prepare half of sql column names
object_colnames = list(df.select_dtypes('object').drop('Title',axis=1).columns)

sql_text_cols = [f"{col} TEXT(255)" for col in object_colnames]
sql_text_cols = [f"Title VARCHAR(255) PRIMARY KEY",*sql_text_cols]
sql_text_cols=','.join(sql_text_cols)

## Get Integer columns and prepare half of sql column names
int_colnames = list(df.select_dtypes('int').columns)
sql_int_cols = [f"{col} INT" for col in int_colnames]
sql_int_cols=', '.join(sql_int_cols)

## Join together all column names
cols_for_table_cmd = ', '.join([sql_text_cols,sql_int_cols])
cols_for_table_cmd
# Out:
# 'Title VARCHAR(255) PRIMARY KEY,RepoType TEXT(255),Est_Student_time TEXT(255),V21_repo TEXT(255),GitHub_Repo_V2 TEXT(255),Notes_from_Learning_Goals TEXT(255),Section_number TEXT(255),Section_Title TEXT(255),Module TEXT(255), number_index INT'

# %% [markdown]
# ### Executing Commands

# %%
## Make students table
db = 'lessons'
table='repos'
cur.execute(f"USE {db};")

cmd = f"DROP TABLE IF EXISTS {table};"
cur.execute(cmd)


create_cmd = f"CREATE TABLE {table}({cols_for_table_cmd});" 
print(create_cmd)
cur.execute(create_cmd)
print('Success!')
# Out:
# CREATE TABLE repos(Title VARCHAR(255) PRIMARY KEY,RepoType TEXT(255),Est_Student_time TEXT(255),V21_repo TEXT(255),GitHub_Repo_V2 TEXT(255),Notes_from_Learning_Goals TEXT(255),Section_number TEXT(255),Section_Title TEXT(255),Module TEXT(255), number_index INT);
# Success!

# %%
df_sql = pd.read_sql_table('repos',engine)
df_sql
# Out:
# Empty DataFrame
# Columns: [Title, RepoType, Est_Student_time, V21_repo, GitHub_Repo_V2, Notes_from_Learning_Goals, Section_number, Section_Title, Module, number_index]
# Index: []

# %%
df.head()
# Out:
#    number_index                                             Title RepoType  \
# 0             0                                           Welcome   Readme
# 1             1                                          Blogging   Readme
# 2             2  Getting Started with Data Science - Introduction   Readme
# 3             3                   Problems Data Science Can Solve   Readme
# 4             4                          The Data Science Process   Readme
#
#   Est_Student_time                                           V21_repo  \
# 0         00:05:00  https://github.com/learn-co-curriculum/dsc-wel...
# 1         00:15:00  https://github.com/learn-co-curriculum/dsc-wel...
# 2         00:05:00  https://github.com/learn-co-curriculum/dsc-int...
# 3         00:10:00  https://github.com/learn-co-curriculum/dsc-pro...
# 4         00:10:00  https://github.com/learn-co-curriculum/dsc-the...
#
#                                       GitHub_Repo_V2  \
# 0  https://github.com/learn-co-curriculum/dsc-wel...
# 1  https://github.com/learn-co-curriculum/dsc-wel...
# 2  https://github.com/learn-co-curriculum/dsc-int...
# 3  https://github.com/learn-co-curriculum/dsc-pro...
# 4  https://github.com/learn-co-curriculum/dsc-the...
#
#                       Notes_from_Learning_Goals Section_number  \
# 0                                           NaN     Section 00
# 1                                           NaN     Section 00
# 2                                           NaN     Section 01
# 3  Describe the problems data science can solve     Section 01
# 4      Describe the full data science process\n     Section 01
#
#                        Section_Title   Module
# 0                            Welcome  Welcome
# 1                            Welcome  Welcome
# 2  Getting Started with Data Science    Mod 1
# 3  Getting Started with Data Science    Mod 1
# 4  Getting Started with Data Science    Mod 1

# %%
help(df.to_sql)
# Out:
# Help on method to_sql in module pandas.core.generic:
#
# to_sql(name:str, con, schema=None, if_exists:str='fail', index:bool=True, index_label=None, chunksize=None, dtype=None, method=None) -> None method of pandas.core.frame.DataFrame instance
#     Write records stored in a DataFrame to a SQL database.
#
#     Databases supported by SQLAlchemy [1]_ are supported. Tables can be
#     newly created, appended to, or overwritten.
#
#     Parameters
#     ----------
#     name : str
#         Name of SQL table.
#     con : sqlalchemy.engine.(Engine or Connection) or sqlite3.Connection
#         Using SQLAlchemy makes it possible to use any DB supported by that
#         library. Legacy support is provided for sqlite3.Connection objects. The user
#         is responsible for engine disposal and connection closure for the SQLAlchemy
#         connectable See `here                 <https://docs.sqlalchemy.org/en/13/core/connections.html>`_.
#
#     schema : str, optional
#         Specify the schema (if database flavor supports this). If None, use
#         default schema.
#     if_exists : {'fail', 'replace', 'append'}, default 'fail'
#         How to behave if the table already exists.
#
#         * fail: Raise a ValueError.
#         * replace: Drop the table before inserting new values.
#         * append: Insert new values to the existing table.
#
#     index : bool, default True
#         Write DataFrame index as a column. Uses `index_label` as the column
#         name in the table.
#     index_label : str or sequence, default None
#         Column label for index column(s). If None is given (default) and
#         `index` is True, then the index names are used.
#         A sequence should be given if the DataFrame uses MultiIndex.
#     chunksize : int, optional
#         Specify the number of rows in each batch to be written at a time.
#         By default, all rows will be written at once.
#     dtype : dict or scalar, optional
#         Specifying the datatype for columns. If a dictionary is used, the
#         keys should be the column names and the values should be the
#         SQLAlchemy types or strings for the sqlite3 legacy mode. If a
#         scalar is provided, it will be applied to all columns.
#     method : {None, 'multi', callable}, optional
#         Controls the SQL insertion clause used:
#
#         * None : Uses standard SQL ``INSERT`` clause (one per row).
#         * 'multi': Pass multiple values in a single ``INSERT`` clause.
#         * callable with signature ``(pd_table, conn, keys, data_iter)``.
#
#         Details and a sample callable implementation can be found in the
#         section :ref:`insert method <io.sql.method>`.
#
#         .. versionadded:: 0.24.0
#
#     Raises
#     ------
#     ValueError
#         When the table already exists and `if_exists` is 'fail' (the
#         default).
#
#     See Also
#     --------
#     read_sql : Read a DataFrame from a table.
#
#     Notes
#     -----
#     Timezone aware datetime columns will be written as
#     ``Timestamp with timezone`` type with SQLAlchemy if supported by the
#     database. Otherwise, the datetimes will be stored as timezone unaware
#     timestamps local to the original timezone.
#
#     .. versionadded:: 0.24.0
#
#     References
#     ----------
#     .. [1] https://docs.sqlalchemy.org
#     .. [2] https://www.python.org/dev/peps/pep-0249/
#
#     Examples
#     --------
#     Create an in-memory SQLite database.
#
#     >>> from sqlalchemy import create_engine
#     >>> engine = create_engine('sqlite://', echo=False)
#
#     Create a table from scratch with 3 rows.
#
#     >>> df = pd.DataFrame({'name' : ['User 1', 'User 2', 'User 3']})
#     >>> df
#          name
#     0  User 1
#     1  User 2
#     2  User 3
#
#     >>> df.to_sql('users', con=engine)
#     >>> engine.execute("SELECT * FROM users").fetchall()
#     [(0, 'User 1'), (1, 'User 2'), (2, 'User 3')]
#
#     An `sqlalchemy.engine.Connection` can also be passed to to `con`:
#     >>> with engine.begin() as connection:
#     ...     df1 = pd.DataFrame({'name' : ['User 4', 'User 5']})
#     ...     df1.to_sql('users', con=connection, if_exists='append')
#
#     This is allowed to support operations that require that the same
#     DBAPI connection is used for the entire operation.
#
#     >>> df2 = pd.DataFrame({'name' : ['User 6', 'User 7']})
#     >>> df2.to_sql('users', con=engine, if_exists='append')
#     >>> engine.execute("SELECT * FROM users").fetchall()
#     [(0, 'User 1'), (1, 'User 2'), (2, 'User 3'),
#      (0, 'User 4'), (1, 'User 5'), (0, 'User 6'),
#      (1, 'User 7')]
#
#     Overwrite the table with just ``df2``.
#
#     >>> df2.to_sql('users', con=engine, if_exists='replace',
#     ...            index_label='id')
#     >>> engine.execute("SELECT * FROM users").fetchall()
#     [(0, 'User 6'), (1, 'User 7')]
#
#     Specify the dtype (especially useful for integers with missing values).
#     Notice that while pandas is forced to store the data as floating point,
#     the database supports nullable integers. When fetching the data with
#     Python, we get back integer scalars.
#
#     >>> df = pd.DataFrame({"A": [1, None, 2]})
#     >>> df
#          A
#     0  1.0
#     1  NaN
#     2  2.0
#
#     >>> from sqlalchemy.types import Integer
#     >>> df.to_sql('integers', con=engine, index=False,
#     ...           dtype={"A": Integer()})
#
#     >>> engine.execute("SELECT * FROM integers").fetchall()
#     [(1,), (None,), (2,)]

# %%
## Saving to db
df.to_sql('repos',engine,if_exists='replace',index=False)

# %% [markdown]
# # TESTING CREATED DATABASE

# %% [markdown]
# ## Testing with Pandas

# %%
df_sql = pd.read_sql_table('repos',engine)
df_sql
# Out:
#      number_index                                             Title RepoType  \
# 0               0                                           Welcome   Readme
# 1               1                                          Blogging   Readme
# 2               2  Getting Started with Data Science - Introduction   Readme
# 3               3                   Problems Data Science Can Solve   Readme
# 4               4                          The Data Science Process   Readme
# ..            ...                                               ...      ...
# 619           619                    Spark Reading Into A DataFrame     None
# 620           620                        Setting Up Scala and Spark     None
# 621           621                         Spark Docker Installation     None
# 622           622                           Spark DataFrame Joining     None
# 623           623                       Machine Learning With Spark     None
#
#     Est_Student_time                                           V21_repo  \
# 0           00:05:00  https://github.com/learn-co-curriculum/dsc-wel...
# 1           00:15:00  https://github.com/learn-co-curriculum/dsc-wel...
# 2           00:05:00  https://github.com/learn-co-curriculum/dsc-int...
# 3           00:10:00  https://github.com/learn-co-curriculum/dsc-pro...
# 4           00:10:00  https://github.com/learn-co-curriculum/dsc-the...
# ..               ...                                                ...
# 619             None                                               None
# 620             None                                               None
# 621             None                                               None
# 622             None                                               None
# 623             None                                               None
#
#                                         GitHub_Repo_V2  \
# 0    https://github.com/learn-co-curriculum/dsc-wel...
# 1    https://github.com/learn-co-curriculum/dsc-wel...
# 2    https://github.com/learn-co-curriculum/dsc-int...
# 3    https://github.com/learn-co-curriculum/dsc-pro...
# 4    https://github.com/learn-co-curriculum/dsc-the...
# ..                                                 ...
# 619  https://github.com/learn-co-curriculum/dsc-ent...
# 620  https://github.com/learn-co-curriculum/dsc-ent...
# 621  https://github.com/learn-co-curriculum/dsc-ent...
# 622  https://github.com/learn-co-curriculum/dsc-ent...
# 623  https://github.com/learn-co-curriculum/dsc-ent...
#
#                         Notes_from_Learning_Goals  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3    Describe the problems data science can solve
# 4        Describe the full data science process\n
# ..                                            ...
# 619                                          None
# 620                                          None
# 621                                          None
# 622                                          None
# 623                                          None
#
#                                         Section_number  \
# 0                                           Section 00
# 1                                           Section 00
# 2                                           Section 01
# 3                                           Section 01
# 4                                           Section 01
# ..                                                 ...
# 619  Section Enterprise 2  [not part of core curric...
# 620  Section Enterprise 2  [not part of core curric...
# 621  Section Enterprise 2  [not part of core curric...
# 622  Section Enterprise 2  [not part of core curric...
# 623  Section Enterprise 2  [not part of core curric...
#
#                          Section_Title      Module
# 0                              Welcome     Welcome
# 1                              Welcome     Welcome
# 2    Getting Started with Data Science       Mod 1
# 3    Getting Started with Data Science       Mod 1
# 4    Getting Started with Data Science       Mod 1
# ..                                 ...         ...
# 619                              Spark  Enterprise
# 620                              Spark  Enterprise
# 621                              Spark  Enterprise
# 622                              Spark  Enterprise
# 623                              Spark  Enterprise
#
# [624 rows x 10 columns]

# %%
# df_students = pd.read_sql_table('students',engine)
# df_students

# %% [markdown]
# ## Testing via MySQL connection

# %%
mydb

# %%
cur.execute("SELECT * FROM repos")
cur.fetchall()
# Out:
# [(0,
#   'Welcome',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-welcome-intro',
#   'https://github.com/learn-co-curriculum/dsc-welcome-intro',
#   None,
#   'Section 00',
#   'Welcome',
#   'Welcome'),
#  (1,
#   'Blogging',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-welcome-blogging-v2-1',
#   'https://github.com/learn-co-curriculum/dsc-welcome-blogging',
#   None,
#   'Section 00',
#   'Welcome',
#   'Welcome'),
#  (2,
#   'Getting Started with Data Science - Introduction',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-introduction-section-intro',
#   'https://github.com/learn-co-curriculum/dsc-introduction-section-intro',
#   None,
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (3,
#   'Problems Data Science Can Solve',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-problems-data-science-can-solve',
#   'https://github.com/learn-co-curriculum/dsc-problems-data-science-can-solve',
#   'Describe the problems data science can solve',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (4,
#   'The Data Science Process',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-the-data-science-process',
#   'https://github.com/learn-co-curriculum/dsc-the-data-science-process',
#   'Describe the full data science process\n',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (5,
#   'Setting up a Professional Data Science Environment - Installation',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-data-science-env-installation-v2-1',
#   'https://github.com/learn-co-curriculum/dsc-data-science-env',
#   'Install Git, Install Anaconda',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (6,
#   'Setting up a Professional Data Science Environment - Setup',
#   'Readme',
#   None,
#   'https://github.com/learn-co-curriculum/dsc-data-science-env-setup-v2-1',
#   None,
#   'Summarise why virtual environments are used, Use a virtual environment, Use basic commands to navigate the command line',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (7,
#   'Working with Lessons on Learn',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-learn-lessons',
#   'https://github.com/learn-co-curriculum/dsc-learn-lessons',
#   'Use basic commands to navigate the command line, Use git clone to clone a repository, Use bash commands to create new files and folders, Perform cell operations within Jupyter Notebooks',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (8,
#   'Working with Lessons on Learn - Lab',
#   'Lab',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-learn-lessons-lab',
#   'https://github.com/learn-co-curriculum/dsc-learn-lessons-lab',
#   'Use basic commands to navigate the command line, Use git clone to clone a repository, Use bash commands to create new files and folders, Perform cell operations within Jupyter Notebooks',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (9,
#   'Your First Data Science Codealong!',
#   'CodeAlong',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-first-codealong',
#   'https://github.com/learn-co-curriculum/dsc-first-codealong',
#   'Use import statements to import and alias python modules, Perform cell operations within Jupyter Notebooks',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (10,
#   'Introduction to Variables: Variable Assignment',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-variable-assignment-intro',
#   'https://github.com/learn-co-curriculum/dsc-variable-assignment-intro',
#   'Assign and declare a python variable',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (11,
#   'Introduction to Variables: Strings',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-strings',
#   'https://github.com/learn-co-curriculum/dsc-strings',
#   'Inspect documentation with various methods, Apply string methods to make changes to a string',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (12,
#   'Introduction to Variables: Strings - Lab',
#   'Lab',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-strings-lab',
#   'https://github.com/learn-co-curriculum/dsc-strings-lab',
#   'Apply string methods to make changes to a string, Use concatenation to combine strings',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (13,
#   'Introduction to Variables: Numeric Types and Booleans',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-floats-ints-booleans',
#   'https://github.com/learn-co-curriculum/dsc-floats-ints-booleans',
#   'Use different numeric data types, Use Boolean data types, Distinguish the difference between numeric datatypes, Perform basic mathematical operations with numeric datatypes',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (14,
#   'Introduction to Variables: Strings and Numeric Types - Lab',
#   'Lab',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-strings-floats-ints-lab',
#   'https://github.com/learn-co-curriculum/dsc-strings-floats-ints-lab',
#   'Apply string methods to make changes to a string, Perform basic mathematical operations with numeric datatypes, Use concatenation to combine strings',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (15,
#   'Introduction to Variables: Variable Assignment - Lab',
#   'Lab',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-variable-assignment-lab',
#   'https://github.com/learn-co-curriculum/dsc-variable-assignment-lab',
#   'Assign and declare a python variable',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (16,
#   'Control Flow: Conditionals',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-conditionals',
#   'https://github.com/learn-co-curriculum/dsc-conditionals',
#   'Use Python condition statements',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (17,
#   'Control Flow: Conditionals - Lab',
#   'Lab',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-conditionals-lab',
#   'https://github.com/learn-co-curriculum/dsc-conditionals-lab',
#   'Use Python condition statements',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (18,
#   'Working with Lists',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-lists',
#   'https://github.com/learn-co-curriculum/dsc-lists',
#   'Change elements of a list, Use indexing to access element in a list, Apply list methods to make changes to a list',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (19,
#   'Working with Lists - Lab',
#   'Lab',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-lists-lab',
#   'https://github.com/learn-co-curriculum/dsc-lists-lab',
#   'Change elements of a list, Use indexing to access element in a list, Apply list methods to make changes to a list',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (20,
#   'Working with Dictionaries',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-dictionaries',
#   'https://github.com/learn-co-curriculum/dsc-dictionaries',
#   'Access keys and values in a dictionary, Assign values in a dictionary',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (21,
#   'Working with Dictionaries - Lab',
#   'Lab',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-dictionaries-lab',
#   'https://github.com/learn-co-curriculum/dsc-dictionaries-lab',
#   'Access keys and values in a dictionary, Assign values in a dictionary',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (22,
#   'Looping Over Collections',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-looping-over-collections',
#   'https://github.com/learn-co-curriculum/dsc-looping-over-collections',
#   'Use a for loop to iterate over a collection',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (23,
#   'Looping Over Collections - Lab',
#   'Lab',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-looping-over-collections-lab',
#   'https://github.com/learn-co-curriculum/dsc-looping-over-collections-lab',
#   'Use a for loop to iterate over a collection',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (24,
#   'Data Visualization',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-data-viz',
#   'https://github.com/learn-co-curriculum/dsc-data-viz',
#   'Use matplotlib to create a histogram, Use matplotlib to create a scatterplot, Interpret a histogram to gain insight about a distribution of data',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (25,
#   'Data Visualization - Lab',
#   'Lab',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-data-viz-lab',
#   'https://github.com/learn-co-curriculum/dsc-data-viz-lab',
#   'Use matplotlib to create a histogram, Use matplotlib to create a scatterplot, Interpret a histogram to gain insight about a distribution of data',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (26,
#   'Project: Analyzing Macbeth',
#   'Lab',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-analyzing-macbeth-project-v2-1',
#   'https://github.com/learn-co-curriculum/analyzing-macbeth-project',
#   'Use a for loop to iterate over a collection, Apply string methods to make changes to a string, Assign values in a dictionary',
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (27,
#   'Getting Started with Data Science - Recap',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-pandas-data-cleaning-recap',
#   'https://github.com/learn-co-curriculum/dsc-pandas-data-cleaning-recap',
#   None,
#   'Section 01',
#   'Getting Started with Data Science',
#   'Mod 1'),
#  (28,
#   'Bash and Git - Introduction',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-git-bash-collab-intro',
#   'https://github.com/learn-co-curriculum/dsc-git-bash-collab-intro',
#   None,
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (29,
#   'The Bash Shell',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-bash-shell',
#   'https://github.com/learn-co-curriculum/dsc-bash-shell',
#   'Navigate between directories using the Bash shell',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (30,
#   'Git Version Control 101',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-git-version-control-101',
#   'https://github.com/learn-co-curriculum/dsc-git-version-control-101',
#   'Describe the purpose of version control and git',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (31,
#   'Getting Started with Git',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-git-intro',
#   'https://github.com/learn-co-curriculum/dsc-git-intro',
#   'Use git clone to clone a repository, Use git add, git commit, and git push to make changes to a repository, Compare local and remote repositories, Describe the difference between a forked and a cloned respository',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (32,
#   'Quiz: Git Basics',
#   'Quiz',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-git-intro-qz',
#   'https://github.com/learn-co-curriculum/dsc-git-intro-qz',
#   'Use git clone to clone a repository, Use git add, git commit, and git push to make changes to a repository, Use git commands to see status of repository',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (33,
#   'Practicing Git',
#   'Readme',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-git-practice',
#   'https://github.com/learn-co-curriculum/dsc-git-practice',
#   'Create a new git repository, Compare local and remote repositories, Use git add, git commit, and git push to make changes to a repository',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (34,
#   'Collaborating with Git Branches',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-git-branches',
#   'https://github.com/learn-co-curriculum/dsc-git-branches',
#   'Create a new branch\n\n, Explain branches and their purpose in git, Use git merge to merge different branches, Switch between branches\n, Identify and fix merge conflicts when merging branches\n',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (35,
#   'Git Merge - Lab',
#   'Lab',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-git-merge-lab',
#   'https://github.com/learn-co-curriculum/dsc-git-merge-lab',
#   'Create a new branch\n\n, Explain branches and their purpose in git, Use git merge to merge different branches, Switch between branches\n',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (36,
#   'Git Stash - Lab',
#   'Lab',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-git-stash-lab',
#   'https://github.com/learn-co-curriculum/dsc-git-stash-lab',
#   'Use git stash to store changes to files, Identify and fix merge conflicts when merging branches\n',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (37,
#   'Git Resources',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-git-resources',
#   'https://github.com/learn-co-curriculum/dsc-git-resources',
#   'Use resources to expand Git and Markdown skills',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (38,
#   'Code Best Practices: Commenting, Standardizing Layout, PEP 8',
#   'Readme',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-PEP8',
#   'https://github.com/learn-co-curriculum/dsc-PEP8',
#   'List the conventions defined in PEP8',
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (39,
#   'Bash and Git - Recap',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-git-collab-recap',
#   'https://github.com/learn-co-curriculum/dsc-git-collab-recap',
#   None,
#   'Section 02',
#   'Bash and Git',
#   'Mod 1'),
#  (40,
#   'Control flow, Functions, and Statistics - Introduction',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-python-section-intro',
#   'https://github.com/learn-co-curriculum/dsc-python-section-intro',
#   None,
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (41,
#   'Built-in Python Operators, Functions and Methods',
#   'Readme',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-python-operators-functions-and-methods',
#   'https://github.com/learn-co-curriculum/dsc-python-operators-functions-and-methods',
#   'Use built-in Python functions and methods, Describe the difference between a function and a method, Use comparison operators to compare objects, Use logical operators to incorporate multiple conditions, Use identity operators to confirm the identity of an object',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (42,
#   'Built-in Python Operators, Functions and Methods - Lab',
#   'Lab',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-python-operators-functions-and-methods-lab',
#   'https://github.com/learn-co-curriculum/dsc-python-operators-functions-and-methods-lab',
#   'Use built-in Python functions and methods, Use comparison operators to compare objects, Use logical operators to incorporate multiple conditions, Use identity operators to confirm the identity of an object',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (43,
#   'While Loops, Break and Continue',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-while-loops-break-and-continue',
#   'https://github.com/learn-co-curriculum/dsc-while-loops-break-and-continue',
#   'Use a while loop, Use break and continue to add control flow to a while loop',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (44,
#   'While Loops, Break and Continue - Lab',
#   'Lab',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-while-loops-break-and-continue-lab',
#   'https://github.com/learn-co-curriculum/dsc-while-loops-break-and-continue-lab',
#   'Use a while loop, Use break and continue to add control flow to a while loop',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (45,
#   'Using Nested Loops',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-using-nested-loops',
#   'https://github.com/learn-co-curriculum/dsc-using-nested-loops',
#   'Use a nested loop when it is appropriate',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (46,
#   'Using Nested Loops - Lab',
#   'Lab',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-using-nested-loops-lab',
#   'https://github.com/learn-co-curriculum/dsc-using-nested-loops-lab',
#   'Use a nested loop when it is appropriate',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (47,
#   'Creating Functions',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-creating-functions',
#   'https://github.com/learn-co-curriculum/dsc-creating-functions',
#   'Declare and use a basic function',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (48,
#   'Creating Functions - Lab',
#   'Lab',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-creating-functions-lab',
#   'https://github.com/learn-co-curriculum/dsc-creating-functions-lab',
#   'Declare and use a basic function',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (49,
#   'Functions with Arguments',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-functions-with-arguments',
#   'https://github.com/learn-co-curriculum/dsc-functions-with-arguments',
#   'Declare and use a function with arguments',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (50,
#   'Functions with Arguments - Lab',
#   'Lab',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-functions-with-arguments-lab',
#   'https://github.com/learn-co-curriculum/dsc-functions-with-arguments-lab',
#   'Declare and use a function with arguments',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (51,
#   'User Input and Output in Python',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-user-input-and-output-in-python',
#   'https://github.com/learn-co-curriculum/dsc-user-input-and-output-in-python',
#   'Incorporate input/output functionality in code to allow for user interaction',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (52,
#   'Mathematical notation',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-mathematical-notation',
#   'https://github.com/learn-co-curriculum/dsc-mathematical-notation',
#   'Read and understand basic mathematical notation',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (53,
#   'Measures of Central Tendency',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-measures-of-central-tendency',
#   'https://github.com/learn-co-curriculum/dsc-measures-of-central-tendency',
#   'Compare the different measures of central tendency',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (54,
#   'Measures of Central Tendency - Quiz',
#   'Quiz',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-measures-of-central-tendency-quiz',
#   'https://github.com/learn-co-curriculum/dsc-measures-of-central-tendency-quiz',
#   'Compare the different measures of central tendency',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (55,
#   'Measures of Dispersion',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-measures-of-dispersion',
#   'https://github.com/learn-co-curriculum/dsc-measures-of-dispersion',
#   'Compare the different measures of dispersion, Create a box plot and use it to interpret the spread of data',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (56,
#   'Measures of Dispersion - Quiz',
#   'Quiz',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-measures-of-dispersion-quiz',
#   'https://github.com/learn-co-curriculum/dsc-measures-of-dispersion-quiz',
#   'Compare the different measures of dispersion',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (57,
#   'Implementing Statistics with Functions - Lab',
#   'Larger lab',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-implementing-statistics-with-functions-lab',
#   'https://github.com/learn-co-curriculum/dsc-implementing-statistics-with-functions-lab',
#   'Calculate the measures of central tendency for a dataset, Compare the different measures of central tendency, Calculate the measures of dispersion for a dataset, Compare the different measures of dispersion',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (58,
#   'Covariance and Correlation',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-correlation-covariance',
#   'https://github.com/learn-co-curriculum/dsc-correlation-covariance',
#   'Calculate covariance and correlation, Declare and use a function with arguments',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (59,
#   'Covariance and Correlation - Lab',
#   'Lab',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-correlation-covariance-lab',
#   'https://github.com/learn-co-curriculum/dsc-correlation-covariance-lab',
#   'Distinguish between correlation and causation, Interpret correlation and its relationship to covariance, Calculate covariance and correlation',
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (60,
#   'Control flow, Functions, and Statistics - Recap',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-python-section-recap',
#   'https://github.com/learn-co-curriculum/dsc-python-section-recap',
#   None,
#   'Section 03',
#   'Control flow, Functions, and Statistics',
#   'Mod 1'),
#  (61,
#   'Python Libraries: Numpy and Pandas - Introduction',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-numpy-and-pandas-section-intro',
#   'https://github.com/learn-co-curriculum/dsc-numpy-and-pandas-section-intro',
#   None,
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (62,
#   'Introducing Python Libraries',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-introducing-python-libraries',
#   'https://github.com/learn-co-curriculum/dsc-introducing-python-libraries',
#   'Explain the purpose of common Python libraries in the data science toolkit',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (63,
#   'Introduction to NumPy',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-introduction-to-numpy',
#   'https://github.com/learn-co-curriculum/dsc-introduction-to-numpy',
#   'Describe why numpy is used at times over standard Python, Use broadcasting to perform a math operation on an entire numpy array, Instantiate a numpy array with specified values',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (64,
#   'Getting Started with NumPy',
#   'Readme',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-getting-started-with-numpy',
#   'https://github.com/learn-co-curriculum/dsc-getting-started-with-numpy',
#   'Access the shape of a numpy array, Perform vector and matrix operations with numpy, Use indexing with numpy arrays, Use broadcasting to perform a math operation on an entire numpy array',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (65,
#   'Getting Started with Numpy - Lab',
#   'Lab',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-getting-started-with-numpy-lab',
#   'https://github.com/learn-co-curriculum/dsc-getting-started-with-numpy-lab',
#   'Use broadcasting to perform a math operation on an entire numpy array, Instantiate a numpy array with specified values',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (66,
#   'Accessing Data within Pandas',
#   'Readme',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-accessing-data-with-pandas',
#   'https://github.com/learn-co-curriculum/dsc-accessing-data-with-pandas',
#   'Use pandas methods and attributes to access information about a dataset, Index pandas dataframes with .loc, .iloc, and column names, Use a boolean mask to index pandas series and dataframes',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (67,
#   'Accessing Data within Pandas - Lab',
#   'Lab',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-accessing-data-with-pandas-lab',
#   'https://github.com/learn-co-curriculum/dsc-accessing-data-with-pandas-lab',
#   'Use pandas methods and attributes to access information about a dataset, Index pandas dataframes with .loc, .iloc, and column names, Use a boolean mask to index pandas series and dataframes',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (68,
#   'Importing Data Using Pandas',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-importing-data-using-pandas',
#   'https://github.com/learn-co-curriculum/dsc-importing-data-using-pandas',
#   'Use pandas to import data from a csv and and an excel  spreadsheet, Use pandas to export a dataframe to a file',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (69,
#   'Importing Data Using Pandas - Lab',
#   'Lab',
#   datetime.timedelta(0, 2100),
#   'https://github.com/learn-co-curriculum/dsc-importing-data-using-pandas-lab',
#   'https://github.com/learn-co-curriculum/dsc-importing-data-using-pandas-lab',
#   'Use pandas to import data from a csv and and an excel  spreadsheet',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (70,
#   'Understanding Pandas Series and DataFrames',
#   'Readme',
#   datetime.timedelta(0, 2100),
#   'https://github.com/learn-co-curriculum/dsc-pandas-series-and-dataframes',
#   'https://github.com/learn-co-curriculum/dsc-pandas-series-and-dataframes',
#   'Change datatypes of columns in pandas dataframes, Change the index of a pandas dataframe, Perform operations to change the structure of pandas dataframes, Use the map or apply method to apply a function to a pandas series or dataframe',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (71,
#   'Understanding Pandas Series and DataFrames - Lab',
#   'Lab',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-pandas-series-and-dataframes-lab',
#   'https://github.com/learn-co-curriculum/dsc-pandas-series-and-dataframes-lab',
#   'Change datatypes of columns in pandas dataframes, Change the index of a pandas dataframe, Perform operations to change the structure of pandas dataframes, Use the map or apply method to apply a function to a pandas series or dataframe',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (72,
#   'Statistical Methods in Pandas',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-statistical-methods-in-pandas',
#   'https://github.com/learn-co-curriculum/dsc-statistical-methods-in-pandas',
#   'Calculate summary statistics for a series and dataframe , Use the .apply() or .applymap() methods to apply a function to a pandas series or DataFrame',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (73,
#   'Statistical Methods in Pandas - Lab',
#   'Lab',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-statistical-methods-in-pandas-lab',
#   'https://github.com/learn-co-curriculum/dsc-statistical-methods-in-pandas-lab',
#   'Calculate summary statistics for a series and dataframe , Use the .apply() or .applymap() methods to apply a function to a pandas series or DataFrame',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (74,
#   'Data Visualization with Pandas',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-data-visualization-with-pandas',
#   'https://github.com/learn-co-curriculum/dsc-data-visualization-with-pandas',
#   'Make visualizations using pandas built-in methods',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (75,
#   'Data Privacy and Ethics',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-data-ethics',
#   'https://github.com/learn-co-curriculum/dsc-data-ethics',
#   'Determine whether or not a data science procedure meets an ethics standard',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (76,
#   'Kaggle and The Boston Housing Dataset',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-kaggle-and-boston-housing-dataset',
#   'https://github.com/learn-co-curriculum/dsc-kaggle-and-boston-housing-dataset',
#   'Create a Kaggle account and download a dataset',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (77,
#   'Project - EDA with Pandas Using the Boston Housing Data',
#   'Larger Project',
#   datetime.timedelta(0, 4500),
#   'https://github.com/learn-co-curriculum/dsc-project-eda-with-pandas',
#   'https://github.com/learn-co-curriculum/dsc-project-eda-with-pandas',
#   'Perform a full exploratory data analysis process to gain insight about a dataset',
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (78,
#   'Python Libraries: Numpy and Pandas - Recap',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-numpy-and-pandas-section-recap',
#   'https://github.com/learn-co-curriculum/dsc-numpy-and-pandas-section-recap',
#   None,
#   'Section 04',
#   'Python Libraries: Numpy and Pandas',
#   'Mod 1'),
#  (79,
#   'Data Cleaning in Pandas - Introduction',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-introduction-pandas-etl',
#   'https://github.com/learn-co-curriculum/dsc-introduction-pandas-etl',
#   None,
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (80,
#   'Lambda Functions',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-lambda-functions',
#   'https://github.com/learn-co-curriculum/dsc-lambda-functions',
#   'Create lambda functions to use as arguments of other functions, Describe the purpose of lambda functions, when they should be employed, and their limitations, Use the map or apply method to apply a function to a pandas series or dataframe',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (81,
#   'Lambda Functions - Lab',
#   'Lab',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-lambda-functions-lab',
#   'https://github.com/learn-co-curriculum/dsc-lambda-functions-lab',
#   'Create lambda functions to use as arguments of other functions, Use the map or apply method to apply a function to a pandas series or dataframe',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (82,
#   'Pandas Groupby',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-pandas-groupby',
#   'https://github.com/learn-co-curriculum/dsc-pandas-groupby',
#   'Use groupby methods to aggregate different groups in a dataframe',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (83,
#   'Combining DataFrames with Pandas',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-combining-dataframes-pandas',
#   'https://github.com/learn-co-curriculum/dsc-combining-dataframes-pandas',
#   'Use concatenation to combine dataframes, Use different types of joins to merge dataframes, Determine which type of join is preferred for 2 tables of data and a task',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (84,
#   'Combining DataFrames with Pandas - Lab',
#   'Lab',
#   datetime.timedelta(0, 2400),
#   'https://github.com/learn-co-curriculum/dsc-combining-dataframes-pandas-lab',
#   'https://github.com/learn-co-curriculum/dsc-combining-dataframes-pandas-lab',
#   'Use concatenation to combine dataframes, Use different types of joins to merge dataframes, Determine which type of join is preferred for 2 tables of data and a task',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (85,
#   'Pivot Tables with Pandas',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-pivot-tables-pandas',
#   'https://github.com/learn-co-curriculum/dsc-pivot-tables-pandas',
#   'Describe what is meant by long and wide format data, Use multi-hierarchical indexing to access aggregated data, Use stack and unstack to move between different level of multiindexing, Use pivot to create a more organized aggregated dataframe',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (86,
#   'Pivot Tables with Pandas - Lab',
#   'Lab',
#   datetime.timedelta(0, 7200),
#   'https://github.com/learn-co-curriculum/dsc-pivot-tables-pandas-lab',
#   'https://github.com/learn-co-curriculum/dsc-pivot-tables-pandas-lab',
#   'Describe what is meant by long and wide format data, Use multi-hierarchical indexing to access aggregated data, Use stack and unstack to move between different level of multiindexing, Use pivot to create a more organized aggregated dataframe',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (87,
#   'Dealing with Missing Data',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-dealing-missing-data',
#   'https://github.com/learn-co-curriculum/dsc-dealing-missing-data',
#   'Identify missing values in a dataframe using built-in methods, Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset, Explain why missing values are a problem in data science',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (88,
#   'Dealing with Missing Data - Quiz',
#   'Lab',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-dealing-missing-data-quiz',
#   'https://github.com/learn-co-curriculum/dsc-dealing-missing-data-quiz',
#   'Identify missing values in a dataframe using built-in methods, Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset, Explain why missing values are a problem in data science',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (89,
#   'Dealing with Missing Data - Lab',
#   'Lab',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-dealing-missing-data-lab',
#   'https://github.com/learn-co-curriculum/dsc-dealing-missing-data-lab',
#   'Identify missing values in a dataframe using built-in methods, Explain why missing values are a problem in data science',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (90,
#   'More on missing data',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-more-on-missing-data',
#   'https://github.com/learn-co-curriculum/dsc-more-on-missing-data',
#   'Inspect data for duplicates or extraneous values and remove them, Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset, Determine how the distribution of data is affected by imputing values',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (91,
#   'More on missing data - Lab',
#   'Lab',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-more-on-missing-data-lab',
#   'https://github.com/learn-co-curriculum/dsc-more-on-missing-data-lab',
#   'Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset, Determine how the distribution of data is affected by imputing values',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (92,
#   'Project - Data Cleaning',
#   'Larger Project',
#   datetime.timedelta(0, 10800),
#   'https://github.com/learn-co-curriculum/dsc-data-cleaning-project',
#   'https://github.com/learn-co-curriculum/dsc-data-cleaning-project',
#   'Inspect data for duplicates or extraneous values and remove them, Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset, Identify missing values in a dataframe using built-in methods, Use different types of joins to merge dataframes',
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (93,
#   'Data Cleaning in Pandas - Recap',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-summary-data-cleaning-pandas',
#   'https://github.com/learn-co-curriculum/dsc-summary-data-cleaning-pandas',
#   None,
#   'Section 05',
#   'Data Cleaning in Pandas',
#   'Mod 1'),
#  (94,
#   'Data Visualization - Introduction',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-visualizations-section-intro',
#   'https://github.com/learn-co-curriculum/dsc-visualizations-section-intro',
#   None,
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (95,
#   'Customizing Visualizations with Matplotlib',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-more-practice-with-matplotlib',
#   'https://github.com/learn-co-curriculum/dsc-more-practice-with-matplotlib',
#   'Create a lineplot using linspace, Create labels and titles for visualizations, Use different linestyles within a Matplotlib visualization, Create subplots using a Matplotlib figure',
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (96,
#   'Customizing Visualizations with Matplotlib - Lab',
#   'Lab',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-more-practice-with-matplotlib-lab',
#   'https://github.com/learn-co-curriculum/dsc-more-practice-with-matplotlib-lab',
#   'Create a lineplot using linspace, Create labels and titles for visualizations, Use different linestyles within a Matplotlib visualization, Create subplots using a Matplotlib figure',
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (97,
#   'Subplots and Enumeration - Lab',
#   'Lab',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-subplots-and-enumeration-lab',
#   'https://github.com/learn-co-curriculum/dsc-subplots-and-enumeration-lab',
#   'Use the enumerate function in a for loop to track the index while iterating over a collection, Create subplots using a Matplotlib figure',
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (98,
#   'Data Visualization - Best Practices and Common Mistakes',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-data-viz-best-practices-common-mistakes',
#   'https://github.com/learn-co-curriculum/dsc-data-viz-best-practices-common-mistakes',
#   'Choose a type of visualization that is appropriate for a given set of data, Describe how some types of visualizations can be misleading to viewers',
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (99,
#   'Seaborn',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-seaborn',
#   'https://github.com/learn-co-curriculum/dsc-seaborn',
#   'Construct plots with Seaborn using its pre-built functionality',
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (100,
#   'Seaborn - Lab',
#   'Lab',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-seaborn-lab',
#   'https://github.com/learn-co-curriculum/dsc-seaborn-lab',
#   'Construct plots with Seaborn using its pre-built functionality',
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (101,
#   'Data Visualization - Recap',
#   'Readme',
#   datetime.timedelta(0, 300),
#   'https://github.com/learn-co-curriculum/dsc-visualizations-section-recap',
#   'https://github.com/learn-co-curriculum/dsc-visualizations-section-recap',
#   None,
#   'Section 06',
#   'Data Visualization',
#   'Mod 1'),
#  (102,
#   'SQL and Relational Databases - Introduction',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-sql-introduction-v2-1',
#   'https://github.com/learn-co-curriculum/dsc-sql-introduction',
#   None,
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (103,
#   'Selecting Data',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-selecting-data',
#   'https://github.com/learn-co-curriculum/dsc-selecting-data',
#   'Retrieve all information from a SQL table, Retrieve a subset of columns from a table, Retrieve a subset of records from a table using a WHERE clause, Write SQL queries to filter and order results, Connect to a SQL database using Python',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (104,
#   'Selecting Data - Lab',
#   'Lab',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-selecting-data-lab',
#   'https://github.com/learn-co-curriculum/dsc-selecting-data-lab',
#   'Retrieve all information from a SQL table, Retrieve a subset of columns from a table, Retrieve a subset of records from a table using a WHERE clause, Write SQL queries to filter and order results, Connect to a SQL database using Python',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (105,
#   'Filtering and Ordering',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-filtering-and-ordering',
#   'https://github.com/learn-co-curriculum/dsc-filtering-and-ordering',
#   'Write SQL queries to filter and order results, Limit the number of records returned by a query using LIMIT, Filter results using BETWEEN and IS NULL, Order the results of your queries by using ORDER BY (ASC & DESC)',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (106,
#   'Filtering and Ordering - Lab',
#   'Lab',
#   datetime.timedelta(0, 1500),
#   'https://github.com/learn-co-curriculum/dsc-filtering-and-ordering-lab',
#   'https://github.com/learn-co-curriculum/dsc-filtering-and-ordering-lab',
#   'Write SQL queries to filter and order results, Limit the number of records returned by a query using LIMIT, Filter results using BETWEEN and IS NULL, Order the results of your queries by using ORDER BY (ASC & DESC)',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (107,
#   'Grouping Data with SQL',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-grouping-data-with-sql',
#   'https://github.com/learn-co-curriculum/dsc-grouping-data-with-sql',
#   'Use Group By statements in SQL to apply aggregate functions like: COUNT, MAX, MIN, and SUM, Describe the relationship between aggregate functions and GROUP BY statements, Create an alias in a SQL query, Compare the difference between the where and having clause, Use the having clause to compare different aggregates',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (108,
#   'Grouping Data with SQL - Lab',
#   'Lab',
#   datetime.timedelta(0, 2100),
#   'https://github.com/learn-co-curriculum/dsc-grouping-data-with-sql-lab',
#   'https://github.com/learn-co-curriculum/dsc-grouping-data-with-sql-lab',
#   'Use Group By statements in SQL to apply aggregate functions like: COUNT, MAX, MIN, and SUM, Describe the relationship between aggregate functions and GROUP BY statements, Create an alias in a SQL query, Compare the difference between the where and having clause, Use the having clause to compare different aggregates',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (109,
#   'Join Statements',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-join-statements',
#   'https://github.com/learn-co-curriculum/dsc-join-statements',
#   'Compare and contrast the various types of joins, Discuss how primary and foreign keys are used in SQL, Write SQL queries that make use of various types of Joins, Decide and perform whichever type of join is best for retrieving desired data',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (110,
#   'Join Statements - Lab',
#   'Lab',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-join-statements-lab',
#   'https://github.com/learn-co-curriculum/dsc-join-statements-lab',
#   'Compare and contrast the various types of joins, Discuss how primary and foreign keys are used in SQL, Write SQL queries that make use of various types of Joins, Decide and perform whichever type of join is best for retrieving desired data',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (111,
#   'One-to-Many and Many-to-Many Joins',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-one-to-many-and-many-to-many-joins',
#   'https://github.com/learn-co-curriculum/dsc-one-to-many-and-many-to-many-joins',
#   'Explain one-to-many and many-to-many joins as well as implications for the size of query results, Query data using one-to-many and many-to-many joins',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (112,
#   'One-to-Many and Many-to-Many Joins - Lab',
#   'Lab',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-one-to-many-and-many-to-many-joins-lab',
#   'https://github.com/learn-co-curriculum/dsc-one-to-many-and-many-to-many-joins-lab',
#   'Explain one-to-many and many-to-many joins as well as implications for the size of query results, Query data using one-to-many and many-to-many joins',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (113,
#   'SQL Subqueries',
#   'Readme',
#   datetime.timedelta(0, 1800),
#   'https://github.com/learn-co-curriculum/dsc-sql-subqueries',
#   'https://github.com/learn-co-curriculum/dsc-sql-subqueries',
#   'Write subqueries to decompose complex queries',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (114,
#   'SQL Subqueries - Lab',
#   'Lab',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-sql-subqueries-lab',
#   'https://github.com/learn-co-curriculum/dsc-sql-subqueries-lab',
#   'Write subqueries to decompose complex queries',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (115,
#   'Using SQL with Pandas',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-using-sql-with-pandas',
#   'https://github.com/learn-co-curriculum/dsc-using-sql-with-pandas',
#   'Query dataframes with SQL using the pandasql library, Compare accessing data in a dataframe using query methods and conditional logic',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (116,
#   'Using SQL with Pandas - Lab',
#   'Lab',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-using-sql-with-pandas-lab',
#   'https://github.com/learn-co-curriculum/dsc-using-sql-with-pandas-lab',
#   'Query dataframes with SQL using the pandasql library, Compare accessing data in a dataframe using query methods and conditional logic',
#   'Section 07',
#   'SQL and Relational Databases',
#   'Mod 1'),
#  (117,
#   'SQL Database Data Types',
#   'Readme',
#   datetime.timedelta(0, 900),
#   'https://github.com/learn-co-curriculum/dsc-sql-database-data-types',
#   'https://github.com/learn-co-curriculum/dsc-sql-database-data-types',
#   'Describe how datatypes operate within databases and explain why they are necessary, Compare the 4 different types of data you can store in a SQLite database',
#   'Section 07',
# ...
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (569,
#   'Convolutional NN: Visualizing Intermediate Activations',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-visualizing-intermediate-activations',
#   'https://github.com/learn-co-curriculum/dsc-visualizing-intermediate-activations',
#   'Load a saved Keras model, Use Keras methods to visualize the activation functions in CNNs',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (570,
#   'Convolutional NN: Visualizing Activation Functions - Lab',
#   'Lab',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-visualizing-activation-functions-lab',
#   'https://github.com/learn-co-curriculum/dsc-visualizing-activation-functions-lab',
#   'Load a saved Keras model, Use Keras methods to visualize the activation functions in CNNs',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (571,
#   'Convolutional NN: Section Recap',
#   'Readme',
#   datetime.timedelta(0, 1200),
#   'https://github.com/learn-co-curriculum/dsc-cnn-recap',
#   'https://github.com/learn-co-curriculum/dsc-cnn-recap',
#   None,
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (572,
#   'Transfer Learning: Introduction',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-transfer-learning-intro',
#   'https://github.com/learn-co-curriculum/dsc-transfer-learning-intro',
#   None,
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (573,
#   'Transfer Learning: Using Pretrained Networks',
#   'Readme',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-using-pretrained-networks',
#   'https://github.com/learn-co-curriculum/dsc-using-pretrained-networks',
#   'Describe the benefits of using pretrained networks, Explain how pre-trained neural networks are used for feature extraction, Explain what "freezing" and "unfreezing" a layer means in a neural network',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (574,
#   'Transfer Learning: Using Pretrained Networks - Codealong',
#   'CodeAlong',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-using-pretrained-networks-codealong',
#   'https://github.com/learn-co-curriculum/dsc-using-pretrained-networks-codealong',
#   'Use Keras to adapt a pretrained CNN, Implement feature engineering and fine tuning on a pre-trained model, Explain what "freezing" and "unfreezing" a layer means in a neural network',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (575,
#   'Transfer Learning: Image Classification - Lab',
#   'Lab',
#   datetime.timedelta(0, 18000),
#   'https://github.com/learn-co-curriculum/dsc-image-classification-lab',
#   'https://github.com/learn-co-curriculum/dsc-image-classification-lab',
#   'Compare and apply multiple techniques for tuning a model using data augmentation and pretrained models',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (576,
#   'Transfer Learning: Section Recap',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-transfer-learning-recap',
#   'https://github.com/learn-co-curriculum/dsc-transfer-learning-recap',
#   None,
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (577,
#   'Deep NLP: Introduction',
#   'Readme',
#   datetime.timedelta(0, 60),
#   'https://github.com/learn-co-curriculum/dsc-deep-nlp-intro',
#   'https://github.com/learn-co-curriculum/dsc-deep-nlp-intro',
#   None,
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (578,
#   'Deep NLP: Word Embeddings',
#   'Readme',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-word-embeddings',
#   'https://github.com/learn-co-curriculum/dsc-word-embeddings',
#   'Compare and contrast word vector embeddings with other text vectorization strategies, Demonstrate how word vectors are structured',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (579,
#   'Deep NLP: Using Word2Vec',
#   'Readme',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-using-word2vec',
#   'https://github.com/learn-co-curriculum/dsc-using-word2vec',
#   'Describe the architecture of the Word2Vec model, Describe the tunable parameters of a Word2Vec model, Train a Word2Vec model and transform words into vectors',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (580,
#   'Deep NLP: Generating Word Embeddings - Lab',
#   'Lab',
#   datetime.timedelta(0, 7200),
#   'https://github.com/learn-co-curriculum/dsc-generating-word-embeddings-lab',
#   'https://github.com/learn-co-curriculum/dsc-generating-word-embeddings-lab',
#   'Train a Word2Vec model and transform words into vectors, Obtain most similar words by using methods associated with word vectors',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (581,
#   'Deep NLP: Classification with Word Embeddings',
#   'Readme',
#   datetime.timedelta(0, 2700),
#   'https://github.com/learn-co-curriculum/dsc-classification-with-word-embeddings',
#   'https://github.com/learn-co-curriculum/dsc-classification-with-word-embeddings',
#   'Use pretrained word embeddings from popular pretrained models such as GloVe, Describe what an embedding layer is in a neural network',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (582,
#   'Deep NLP: Classification with Word Embeddings - Codealong',
#   'CodeAlong',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-classification-with-word-embeddings-codealong',
#   'https://github.com/learn-co-curriculum/dsc-classification-with-word-embeddings-codealong',
#   'Incorporate embedding layers into neural networks using Keras, Use pretrained word embeddings from popular pretrained models such as GloVe',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (583,
#   'Deep NLP: Sequence Model Use Cases',
#   'Readme',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-sequence-model-use-cases',
#   'https://github.com/learn-co-curriculum/dsc-sequence-model-use-cases',
#   'List some of the use cases for Sequence Models, Define a Sequence Model',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (584,
#   'Deep NLP: Understanding Recurrent Neural Networks',
#   'Readme',
#   datetime.timedelta(0, 5400),
#   'https://github.com/learn-co-curriculum/dsc-understanding-recurrent-neural-networks',
#   'https://github.com/learn-co-curriculum/dsc-understanding-recurrent-neural-networks',
#   'Explain back propagation through time, Explain the role time steps play in RNN models',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (585,
#   'Deep NLP: LSTMs and GRUs',
#   'Readme',
#   datetime.timedelta(0, 3600),
#   'https://github.com/learn-co-curriculum/dsc-lstms-and-grus',
#   'https://github.com/learn-co-curriculum/dsc-lstms-and-grus',
#   'Explain why vanishing and exploding gradients exist when training RNNs, Describe the architecture and function of an LSTM cell, Describe the basic architecture and function of a GRU',
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (586,
#   'Deep NLP: Section Recap',
#   'Readme',
#   datetime.timedelta(0, 600),
#   'https://github.com/learn-co-curriculum/dsc-deep-nlp-recap',
#   'https://github.com/learn-co-curriculum/dsc-deep-nlp-recap',
#   None,
#   'Section 43.APPENDIX Mod 4',
#   'Appendix Mod 3',
#   'Mod 4'),
#  (587,
#   'Setting up Spark and Scala',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterpise-hsbc-setting-up-scala-and-spark',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (588,
#   'Scala Basics',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-basics',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (589,
#   'Val and Var',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-val-and-var',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (590,
#   'Primitives',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-primitives',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (591,
#   'Control Statements',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-control-statements',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (592,
#   'Strings',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-strings',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (593,
#   'Methods',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-methods',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (594,
#   'Type Hierarchy',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-type-hierarchy',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (595,
#   'Unit',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-unit',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (596,
#   'Classes',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-classes',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (597,
#   'Case Classes',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-case-classes',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (598,
#   'Infix Operators',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-infix-operators',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (599,
#   'Apply Method',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-apply-method',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (600,
#   'Right Associative Colons',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-right-associative-colons',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (601,
#   'Options',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-options',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (602,
#   'Objects',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-objects',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (603,
#   'Companion Objects',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-companion-objects',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (604,
#   'Collections',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-collections',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (605,
#   'Functions',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-functions',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (606,
#   'Higher Order Functions',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-higher-order-functions',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (607,
#   'Closures',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-closures',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (608,
#   'Functional Programming',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-scala-functional-programming',
#   None,
#   'Section Enterprise 1  [not part of core curriculum]',
#   'Scala',
#   'Enterprise'),
#  (609,
#   'Spark Basics',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-basics',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (610,
#   'Spark DataFrame Creation',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-dataframe-creation',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (611,
#   'Spark DataFrame Columns',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-dataframe-columns',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (612,
#   'Spark DataFrame Rows',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-dataframe-rows',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (613,
#   'Spark DataFrame Querying',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-dataframe-querying',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (614,
#   'Spark DataFrame Cleaning',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-dataframe-cleaning',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (615,
#   'Spark-SQL',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-sql',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (616,
#   'Datasets',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-datasets',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (617,
#   'Spark Machine Learning With MLLib',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-machine-learning-with-mllib',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (618,
#   'Machine Learning With Spark Lab',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-machine-learning-with-spark-lab',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (619,
#   'Spark Reading Into A DataFrame',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-reading-into-a-dataframe',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (620,
#   'Setting Up Scala and Spark',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterpise-hsbc-setting-up-scala-and-spark',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (621,
#   'Spark Docker Installation',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-docker-installation',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (622,
#   'Spark DataFrame Joining',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-spark-dataframe-joining',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise'),
#  (623,
#   'Machine Learning With Spark',
#   None,
#   None,
#   None,
#   'https://github.com/learn-co-curriculum/dsc-enterprise-hsbc-machine-learning-with-spark',
#   None,
#   'Section Enterprise 2  [not part of core curriculum]',
#   'Spark',
#   'Enterprise')]
